# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['.venv',
#  '.venv-1',
#  '.venv-2',
#  '.vscode',
#  'archive (2)',
#  'archive (2).zip',
#  'assignment.ipynb']

# %%
os.listdir("archive (2)")
# Out:
# ['backpacks.csv',
#  'bath-robe.csv',
#  'bath-towels.csv',
#  'bathroom-accessories.csv',
#  'bedsheets.csv',
#  'belts.csv',
#  'bodysuit.csv',
#  'boots.csv',
#  'boxers.csv',
#  'bra.csv',
#  'bracelet.csv',
#  'briefs.csv',
#  'camisoles.csv',
#  'candle-holders.csv',
#  'caps.csv',
#  'casual-shoes.csv',
#  'chair-cover.csv',
#  'clothing-set.csv',
#  'clutches.csv',
#  'co-ords.csv',
#  'Combined_dataset.csv',
#  'curtains-and-sheers.csv',
#  'cutlery.csv',
#  'dinnerware.csv',
#  'dresses.csv',
#  'duffel-bag.csv',
#  'dungarees.csv',
#  'dupatta.csv',
#  'earrings.csv',
#  'ethnic-dresses.csv',
#  'face-moisturisers.csv',
#  'face-wash-and-cleanser.csv',
#  'flats.csv',
#  'flip-flops.csv',
#  'floor-mats--dhurries.csv',
#  'formal-shoes.csv',
#  'foundation.csv',
#  'gloves.csv',
#  'hair-accessory.csv',
#  'hair-brush-and-comb.csv',
#  'hair-cream-and-mask.csv',
#  'hair-masks.csv',
#  'handbags.csv',
#  'headphones.csv',
#  'heels.csv',
#  'home-fragrance-set.csv',
# ...

# %%
import pandas as pd

df = pd.read_csv("archive (2)/shopping_trends.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("archive (2)/shopping_trends.csv")
#
# ...

# %%
os.listdir("archive (2)")
# Out:
# ['backpacks.csv',
#  'bath-robe.csv',
#  'bath-towels.csv',
#  'bathroom-accessories.csv',
#  'bedsheets.csv',
#  'belts.csv',
#  'bodysuit.csv',
#  'boots.csv',
#  'boxers.csv',
#  'bra.csv',
#  'bracelet.csv',
#  'briefs.csv',
#  'camisoles.csv',
#  'candle-holders.csv',
#  'caps.csv',
#  'casual-shoes.csv',
#  'chair-cover.csv',
#  'clothing-set.csv',
#  'clutches.csv',
#  'co-ords.csv',
#  'Combined_dataset.csv',
#  'curtains-and-sheers.csv',
#  'cutlery.csv',
#  'dinnerware.csv',
#  'dresses.csv',
#  'duffel-bag.csv',
#  'dungarees.csv',
#  'dupatta.csv',
#  'earrings.csv',
#  'ethnic-dresses.csv',
#  'face-moisturisers.csv',
#  'face-wash-and-cleanser.csv',
#  'flats.csv',
#  'flip-flops.csv',
#  'floor-mats--dhurries.csv',
#  'formal-shoes.csv',
#  'foundation.csv',
#  'gloves.csv',
#  'hair-accessory.csv',
#  'hair-brush-and-comb.csv',
#  'hair-cream-and-mask.csv',
#  'hair-masks.csv',
#  'handbags.csv',
#  'headphones.csv',
#  'heels.csv',
#  'home-fragrance-set.csv',
# ...

# %%
import pandas as pd

df = pd.read_csv("archive (2)/Combined_dataset.csv")

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
#  13  product_specifications  1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
df.fillna("Unknown", inplace=True)
# Out:
# C:\Users\Riya Saharan\AppData\Local\Temp\ipykernel_20848\839676283.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("Unknown", inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
high_rating = df[df["rating"] > 4]

high_rating.head()
# Out:
#    product_id           title                         product_description  \
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
# 5    17198778             H&M  Beige & Tan Solid Stoneware Soap Dispenser
#
#    rating  ratings_count  initial_price discount  final_price currency  \
# 1     4.5             67           2899     35.0  "₹2,899.00"      INR
# 2     4.4            226           2999     65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675     52.0  "₹1,675.00"      INR
# 4     4.7             12           2899     17.0  "₹2,899.00"      INR
# 5     4.5             42           1399  Unknown  "₹1,399.00"      INR
#
#                                               images  ...  \
# ...

# %%
df["saved_amount"] = df["initial_price"] - df["final_price"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Riya Saharan\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\Riya Saharan\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Riya Saharan\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ...

# %%
df["initial_price"] = pd.to_numeric(df["initial_price"], errors="coerce")

df["final_price"] = pd.to_numeric(df["final_price"], errors="coerce")

# %%
df["saved_amount"] = df["initial_price"] - df["final_price"]

# %%
df[["title", "initial_price", "final_price", "saved_amount"]].head()
# Out:
#             title  initial_price  final_price  saved_amount
# 0     Lino Perros           3995          NaN           NaN
# 1  Tommy Hilfiger           2899          NaN           NaN
# 2           Lavie           2999          NaN           NaN
# 3          F Gear           1675          NaN           NaN
# 4       MYTRIDENT           2899          NaN           NaN

# %%
df.to_csv("cleaned_data.csv", index=False)

# %% [markdown]
# # Assignment Summary
#
# - Loaded dataset using pandas
# - Explored dataset structure
# - Checked missing values
# - Removed duplicates
# - Filtered high-rated products
# - Created saved_amount column
# - Saved cleaned dataset
